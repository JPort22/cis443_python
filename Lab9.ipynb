# %% [markdown]
# # CIS 443-01 - Analytics Programming
# ## Lab 9
# __Grading ID__: P9941(double click the cell in Jupyter to edit)<br>
# __Due__: Monday, November 22 (by 11:59 PM)<br />
# __Worth__: 25 pts.

# %% [markdown]
# ### Directions
# In the code cell below, write Python code to accomplish the following. Using the techniques demonstrated in Section 10.16, download a data file from <a href="https://www.ncdc.noaa.gov/cag/" target="_blank" rel="noreferrer noopener">NOAA's Climate at a Glance</a> of high (Maximum) temperatures in Louisville, Kentucky for the month of August for all years that the data are available (1948 - 2021). Create a linear regression model using __linregress__ from SciPy. Use the model to predict the high temperature in August 2031.
#
# Test your source code and save your work before submission. (25 pts.)

# %%
#Lab 9
#Grading ID: P9941

import pandas as pd#importing pandas
from scipy import stats#importing stats module
import seaborn as sns#importing seaborn for visual
x = 2031#year to predict
r = 1948#starting year
ky = pd.read_csv('KYlou_hitemp.csv')#reading the csv file
ky.columns = ['Date', 'Temperature', 'Anomaly']#changing column names 
ky.Date = ky.Date.floordiv(100)#doing floor division for the date integer
pd.set_option('precision', 2)#setting precision to 2 for dataframe


linear_regression = stats.linregress(x=ky.Date, y=ky.Temperature)#classifying x and y column/values
linear_regression.slope * x + linear_regression.intercept#predictor year linear equation
linear_regression.slope * r + linear_regression.intercept#starting year linear equation

sns.set_style('whitegrid')#setting up grid
axes = sns.regplot(x=ky.Date, y=ky.Temperature)#making the plot, marks and trend line
axes.set_ylim(80, 98)#range of values
# Out:
# (80.0, 98.0)

# %% [markdown]
# Be sure to save and exit your Jupyter Notebook and Shutdown Jupyter Lab (from the __File__ menu) if using Ananconda before you submit your notebook on Blackboard for grading. If using Colab, be sure to Download (from the __File__ menu) back to your local file system before submitting to Blackboard.
# Make sure you don't submit the empty starting notebook by accident.
